# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("out_bytime.csv").sort_values(by="folder_exptime_s", ascending=True)
minsnr = 20
df = df[df["int_snr_cc"] > minsnr]

dfnew = df.loc[df.groupby("name")["int_snr_cc"].idxmin()].reset_index(drop=True)

# %%
dfnew.columns
# Out:
# Index(['file', 'name', 'int_snr', 'int_snr_cc', 'int_snr_boxcar',
#        'boxcar_halfwidth_sigma', 'ew_used_A', 'cont_e_per_pix',
#        'cont_over_line', 'snr_penalty', 'exptime_s', 'nexpo', 'flux_in_W_m2',
#        'lambda_req_nm', 'fwhm_req_nm', 'line_centre_nm', 'fwhm_out_nm',
#        'dispersion_nm_pix', 'n_orders', 'orders', 'npix', 'flux_fraction',
#        'target_e', 'sky_e', 'const_var', 'limiting_noise', 'frac_var_line',
#        'frac_var_sky', 'frac_var_cont', 'frac_var_const', 'saturated',
#        'nonlinear', 'name_source', 'ew_is_limit', 'folder', 'folder_exptime_s',
#        't_snr5_hr', 't_snr5_cc_hr'],
#       dtype='str')
